# %% [markdown]
# # BME 133 Lab 0
#
# Welcome! This is a Jupyter/IPython notebook, hence the file extension ".ipynb"
#
# Our labs for this class will typically come in the form of a Jupyter notebook. There are two types of cells in a Jupyter Notebook, Markdown (for formatted text) and Code. This is a Markdown cell; double click on it to reveal the underlying Markdown. To view the formatted text again, click the checkmark in the upper right-hand corner of this cell.

# %%
# This is a Python code cell, notice it has a 'play' button on the left and some other options on the right.
# Go ahead and press the play button, or press Shift+Enter on your keyboard, and see what happens
print("Hello World")

# %% [markdown]
# Hopefully you are viewing this file on your computer using Visual Studio Code on an Anaconda kernel, but if you have trouble with installation, today you can use [Jupyter's browser-based platform](https://jupyter.org/try#jupyterlab). In the long-run, it's better to use VSCode because it has more resources than Jupyter alone, and running code locally on your own computer is more secure in terms of data and privacy.
#
# To begin, create a copy of this file using File -> Save as... and name the new file "Lab_0_LastName_FirstName.ipynb" using your last and first name.
#
# This Lab will cover Variables, basic Data Types, Operators, and Commenting

# %% [markdown]
# ## Variables

# %% [markdown]
# Variables in Python can be used to assign values to characters.
# Assign the variable name to the left side, and put the value on the right side.
# Use an equal sign to perform the assignment.
# * Note:
# Variable names are case sensitive.

# %%
x = 1  # assign the integer 1 to the variable x
y = '2'  # assign the string '2' to the variable y
z = "3"  # you can also use double quotes for strings

print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Variable assignments are saved in memory between cells in the notebook (as long as the kernel has not been restarted).

# %%
print(y)
# Out:
# 2

# %% [markdown]
#  If  you re-use the same variable name later, the initial assignment will be replaced.

# %%
y = '4'  # replace the previous assignment of '2' with '4'
print(y)
# Out:
# 4

# %% [markdown]
#  Variable names should be descriptive and make sense in the context of your pipeline.

# %%
apple_color = 'green' # Assign the variable apple_color the value 'green'
print(apple_color)
# Out:
# green

# %% [markdown]
# Executing this next cell won't work. Numbers can't be at the start of the variable.
# Notice what happens when you try to execute this.

# %%
1st_variable = '43110'
print(1st_variable)
# Out:
#   Cell In[9], line 1
#     1st_variable = '43110'
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
#  You can also print strings while including your variable within the string. Here are three possible ways.

# %%
# Old Way, somewhat confusing
print('The value of z is %s' % z)

# New Way #1
name = 'Bob'
print('Hello, {}'.format(name))

# New Way #2
a = 5
b = 10
f'Five plus ten is {a + b} and not {2 * (a + b)}.' # This method is called an f-string
# Out:
# The value of z is 3
# Hello, Bob
# 'Five plus ten is 15 and not 30.'

# %% [markdown]
# ## Data Types

# %% [markdown]
# Variables can store different types of data. Some of the most common types are:
#
# * Text is called a string or: `str`
# * Integers (whole numbers): `int`
# * Floating point numbers (has a decimal point): `float`
# * Boolean (True/False): `bool`
#
# You can determine what data type a variable contains using the `type()` function.

# %%
x = 3
print(type(x))
# Out:
# <class 'int'>

# %%
y = 3.14
print(type(y))
# Out:
# <class 'float'>

# %%
z = True
print(type(z))
# Out:
# <class 'bool'>

# %% [markdown]
# You can change the data type using casting (or type casting) functions such as `int()`, `str()`, or `float()`

# %%
w = float(x)
print(w)
print(type(w))

v = int(y)

print(v)
print(type(v))
# Out:
# 3.0
# <class 'float'>
# 3
# <class 'int'>

# %% [markdown]
# Watch out for floating point errors which occur due to the use of binary in hardware. Some decimals cannot be expressed exactly as binary fractions

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# ## Operators

# %% [markdown]
# Operators in Python perform operations on variable and values. They come in many varieties including: Arithmetic, Assignment, Comparison, and Logical (we'll address logical operators and other types later)
#
# See the <ins>full list</ins> of operators at [W3Schools](https://www.w3schools.com/python/python_operators.asp).

# %% [markdown]
# ### Arithmetic Operators

# %%
x = 2 

# Examples
print(x + 5) # This operator is for addition
print(x - 3) # This operator is for subtraction
print(x * 4) # This operator is for multiplication
print(x / 4) # This operator is for division
print(x ** 2) # This operator is for exponentiation
print(x // 2) # This operator is for floor division
# Out:
# 7
# -1
# 8
# 0.5
# 4
# 1

# %% [markdown]
# The Modulo (also called modulus) operator `%` returns the remainder of a given equation.

# %%
print(5 % 2)
# Out:
# 1

# %% [markdown]
# ### Comparison Operators
# * Note the kind of output comparison operators produce.

# %%
# Examples
print(x == 2) # This operator means 'is exactly equal to'
print(x != 2.1) # This operator means 'is not equal to'
print(x < 3) # This operator evaluates whether the magnitude of x is less than that of 3
print(x >= 3) # This operator evaluates whether the magnitude of x is greater than or equal to that of 3
# Out:
# True
# True
# True
# False

# %% [markdown]
# Assignment Operators

# %%
# Examples
y = 5 # This operator assigns the variable name y to the value 5
y += 1 # This operator increases the value of y by the specified amount
y *= 2 # This operator multiplies the value of y by the specified amount
print(y)
# Out:
# 12

# %% [markdown]
# ## Comments

# %%
# This is comment, comments do not affect the code, but are important for programmers to document and understand one another's code and even their own code.

""" 
This is a mutiline comment.
Multiline comments are especially useful in explaining how functions work,
but that's a story for another time.
"""

# %%
# In VSCode, you can quickly comment out multiple lines of code by highlighting them and pressing Ctrl+K+C (Mac: Command+K+C)
# You can uncomment code highlighting it and pressing Ctrl+K+U (Mac: Command+K+U)
# Try running this cell, then uncomment the code and run the cell again.

# a = 10
# b = 5
# eqn = (a * b)
# result = (eqn > 25)
# print(f'The statement that a*b is > 25 is: {result}')

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Excercise 0

# %% [markdown]
# Before running the next code cell, guess what the output will be.

# %%
x = 1  
y = '2'  
z = "3"  

# What do you think output will be?
print(y + z)
# Out:
# 23

# %% [markdown]
# Was the output what you expected? Why do you think it gave the result that it did?

# %%
# Answer here: 23. Yes. Because your concatenating two strings

# %% [markdown]
# ### Excercise 1

# %% [markdown]
# What do you think will happen?

# %%
print(x + int(y))
# Out:
# 3

# %% [markdown]
# What do you think the function `int()` did to the variable `y` ?

# %%
# Answer here: 3. Converts the y string to an integer. so 1 + 2 = 3.

# %% [markdown]
# ### Excercise 2

# %% [markdown]
# Use a casting function to convert the data type of variable `w` into a floating point number.
#
# Check your result using the `type()` function.

# %%
# Answer below:
w = float(24)
print(w) #print the value of w
print(type(w)) #Use the type() function to print the type of w
# Out:
# 24.0
# <class 'float'>

# %% [markdown]
# ### Excercise 3

# %% [markdown]
# What is the difference between the operators `*` and `*=`?

# %%
# Answer here: "*" multiples two operands together. Multiples itself by the operand on the right side and assigns itself the new number.

# %% [markdown]
# ### Excercise 4

# %% [markdown]
# Write an expression that prints True if the integer is even, and False if the interger is Odd. Hint: use the modulo operator `%` to return the remainder.
#
# `6 / 2` returns `3`; division
# `6 % 2` returns `0`; meaning that the remainder is 0

# %%
#Answer here: print(6 % 2 == 0) returns true
# print(5 % 2 == 0) returns false

# %%
print(6 % 2 == 0)
print(5 % 2 == 0)
# Out:
# True
# False

# %% [markdown]
# ### Getting to know you 🤩

# %% [markdown]
# Leave a comment here stating whether you have any coding experience (if so, what language(s)?), and what you hope to gain from this class.

# %%
#Answer here: Rohit - Yes. Two years as a professional software developer in web development using javascript. 
# Neha - C++ and basic python. Intermediate for c++.
# Dania - MatLab - intermediate 

# We all want strengthen our python skills to help and gain practical experience applying coding to biomedical devices and beyond.
